# %%
import re
import matplotlib.pyplot as plt

# %%
file_path = './ckpt/20250316_213148/train_20250316_213148.log'

# 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    log_data = file.read()

# %%
pattern = re.compile(r"Epoch\s+(\d+)\s+\|\s+Train Loss:\s+([\d.]+)\s+\|\s+Val Loss:\s+([\d.]+)")
epochs = []
train_losses = []
val_losses = []

for line in log_data.splitlines():
    match = pattern.search(line)
    if match:
        epochs.append(int(match.group(1)))
        train_losses.append(float(match.group(2)))
        val_losses.append(float(match.group(3)))

# 가장 낮은 validation loss의 에폭 찾기
min_val_loss = min(val_losses)
min_val_index = val_losses.index(min_val_loss)
min_val_epoch = epochs[min_val_index]

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', label="Train Loss")
plt.plot(epochs, val_losses, marker='o', label="Val Loss")
# 최저의 validation loss 지점 표시
plt.scatter([min_val_epoch], [min_val_loss], color='red', zorder=5, label="Lowest Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("clip loss graph")
plt.legend()
plt.grid(True)
plt.show()

# %%
file_path = './ckpt/20250317_012501/train_20250317_012501.log'


# 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    log_data = file.read()

pattern = re.compile(r"Epoch\s+(\d+)\s+\|\s+Train Loss:\s+([\d.]+)\s+\|\s+Val Loss:\s+([\d.]+)")
epochs = []
train_losses = []
val_losses = []

for line in log_data.splitlines():
    match = pattern.search(line)
    if match:
        epochs.append(int(match.group(1)))
        train_losses.append(float(match.group(2)))
        val_losses.append(float(match.group(3)))

# 가장 낮은 validation loss의 에폭 찾기
min_val_loss = min(val_losses)
min_val_index = val_losses.index(min_val_loss)
min_val_epoch = epochs[min_val_index]

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', label="Train Loss")
plt.plot(epochs, val_losses, marker='o', label="Val Loss")
# 최저의 validation loss 지점 표시
plt.scatter([min_val_epoch], [min_val_loss], color='red', zorder=5, label="Lowest Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("clip loss graph")
plt.legend()
plt.grid(True)
plt.show()

# %%
file_path = './ckpt/20250317_164612/train_20250317_164612.log'


# 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    log_data = file.read()

pattern = re.compile(r"Epoch\s+(\d+)\s+\|\s+Train Loss:\s+([\d.]+)\s+\|\s+Val Loss:\s+([\d.]+)")
epochs = []
train_losses = []
val_losses = []

for line in log_data.splitlines():
    match = pattern.search(line)
    if match:
        epochs.append(int(match.group(1)))
        train_losses.append(float(match.group(2)))
        val_losses.append(float(match.group(3)))

# 가장 낮은 validation loss의 에폭 찾기
min_val_loss = min(val_losses)
min_val_index = val_losses.index(min_val_loss)
min_val_epoch = epochs[min_val_index]

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', label="Train Loss")
plt.plot(epochs, val_losses, marker='o', label="Val Loss")
# 최저의 validation loss 지점 표시
plt.scatter([min_val_epoch], [min_val_loss], color='red', zorder=5, label="Lowest Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("clip loss graph")
plt.legend()
plt.grid(True)
plt.show()

# %%
file_path = './ckpt/20250317_191953/train_20250317_191953.log'


# 파일 읽기
with open(file_path, 'r', encoding='utf-8') as file:
    log_data = file.read()

pattern = re.compile(r"Epoch\s+(\d+)\s+\|\s+Train Loss:\s+([\d.]+)\s+\|\s+Val Loss:\s+([\d.]+)")
epochs = []
train_losses = []
val_losses = []

for line in log_data.splitlines():
    match = pattern.search(line)
    if match:
        epochs.append(int(match.group(1)))
        train_losses.append(float(match.group(2)))
        val_losses.append(float(match.group(3)))

# 가장 낮은 validation loss의 에폭 찾기
min_val_loss = min(val_losses)
min_val_index = val_losses.index(min_val_loss)
min_val_epoch = epochs[min_val_index]

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_losses, marker='o', label="Train Loss")
plt.plot(epochs, val_losses, marker='o', label="Val Loss")
# 최저의 validation loss 지점 표시
plt.scatter([min_val_epoch], [min_val_loss], color='red', zorder=5, label="Lowest Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("clip loss graph")
plt.legend()
plt.grid(True)
plt.show()
